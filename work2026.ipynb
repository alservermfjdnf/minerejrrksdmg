# %% [markdown]
# <a href="https://colab.research.google.com/github/alservermfjdnf/minerejrrksdmg/blob/main/work2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
#@title **SSH TMATE**
#@title **DUNG TERMUX DE KET NOI**
# !pkill -9 tmate
# !wget -nc https://github.com/tmate-io/tmate/releases/download/2.4.0/tmate-2.4.0-static-linux-i386.tar.xz &> /dev/null
# !tar --skip-old-files -xvf tmate-2.4.0-static-linux-i386.tar.xz &> /dev/null
# !rm -f nohup.out; bash -ic 'nohup ./tmate-2.4.0-static-linux-i386/tmate -S /tmp/tmate.sock new-session -d & disown -a' >/dev/null 2>&1
# !./tmate-2.4.0-static-linux-i386/tmate -S /tmp/tmate.sock wait tmate-ready
# !./tmate-2.4.0-static-linux-i386/tmate -S /tmp/tmate.sock display -p "#{tmate_ssh} -t"

# %%
#CHAY CAI NAY VA THOAT RA , KHONG DONG TAB
import time

while True:
    print("Skibidi")
    time.sleep(60)

# %% [markdown]
# **Auto Reconnect FOR PC**
#
# Press F12 >>> Select Console>>> Paste this code
# ```
# function ClickConnect() {
#   console.log('Working')
#   document
#     .querySelector('#top-toolbar > colab-connect-button')
#     .shadowRoot.querySelector('#connect')
#     .click()
# }
#
# setInterval(ClickConnect, 60000)
